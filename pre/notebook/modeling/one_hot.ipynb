# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 设置路径

# %%
path_pre = '../../'
path_intermediate_dataset = path_pre + 'intermediate-dataset/'
path_modeling_dataset = path_pre + 'modeling-dataset/'

# %% [markdown]
# ### 加载数据集

# %%
dataset = pd.read_hdf(path_intermediate_dataset + 'dataset.h5')
dataset.head()
# Out:
#    label  sitesetID  positionType  connectionType  telecomsOperator  hour  \
# 0      0          0             3               1                 1     0
# 1      0          0             3               0                 2     0
# 2      0          0             3               0                 3     0
# 3      0          0             3               1                 1     0
# 4      0          0             3               1                 1     0
#
#    hour_weight  age  gender  education     ...       haveBaby  hometown  \
# 0       225349    3       2          1     ...              1         0
# 1       225349    3       2          2     ...              1        13
# 2       225349    4       2          0     ...              5         0
# 3       225349    3       1          1     ...              0         0
# 4       225349    3       1          0     ...              0        13
#
#    residence  user_activity  cat_pref  advertiserID  appPlatform  appCategory  \
# ...

# %%
print(dataset.columns.tolist())
# Out:
# ['label', 'sitesetID', 'positionType', 'connectionType', 'telecomsOperator', 'hour', 'hour_weight', 'age', 'gender', 'education', 'marriageStatus', 'haveBaby', 'hometown', 'residence', 'user_activity', 'cat_pref', 'advertiserID', 'appPlatform', 'appCategory', 'app_popularity', 'is_pref_cat']

# %%
y = dataset['label'].values

# %%
del dataset['label']

# %%
dataset.head()
# Out:
#    sitesetID  positionType  connectionType  telecomsOperator  hour  \
# 0          0             3               1                 1     0
# 1          0             3               0                 2     0
# 2          0             3               0                 3     0
# 3          0             3               1                 1     0
# 4          0             3               1                 1     0
#
#    hour_weight  age  gender  education  marriageStatus  haveBaby  hometown  \
# 0       225349    3       2          1               3         1         0
# 1       225349    3       2          2               0         1        13
# 2       225349    4       2          0               0         5         0
# 3       225349    3       1          1               0         0         0
# 4       225349    3       1          0               1         0        13
#
#    residence  user_activity  cat_pref  advertiserID  appPlatform  appCategory  \
# ...

# %% [markdown]
# ### testset_ol

# %%
testset_ol = pd.read_hdf(path_intermediate_dataset + 'testset_ol.h5')
testset_ol.head()
# Out:
#    instanceID  label  sitesetID  positionType  connectionType  \
# 0           1     -1          0             1               1
# 1         178     -1          0             1               1
# 2       21839     -1          0             1               1
# 3       25947     -1          0             1               1
# 4       26757     -1          0             1               1
#
#    telecomsOperator  hour  hour_weight  age  gender     ...       haveBaby  \
# 0                 3     0       225349    4       2     ...              1
# 1                 2     0       225349    1       2     ...              1
# 2                 1     5        54638    3       2     ...              1
# 3                 3     6        88673    3       2     ...              0
# 4                 3     6        88673    4       2     ...              0
#
#    hometown  residence  user_activity  cat_pref  advertiserID  appPlatform  \
# ...
